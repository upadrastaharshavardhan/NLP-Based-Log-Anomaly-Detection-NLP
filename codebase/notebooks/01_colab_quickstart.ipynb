# %% [markdown]
# # Project 4 – NLP-Based Log Anomaly Detection
#
# Colab Quickstart

# %%
import os
os.chdir("/content/ai-log-anomaly-detection") if os.path.exists("/content/ai-log-anomaly-detection") else None
print("CWD:", os.getcwd())

# %%
# !pip install -q -r requirements.txt

# %%
# !python scripts/generate_data.py --n-samples 6000
# !python scripts/train.py

# %%
from src.pipeline.detector import LogAnomalyDetector
detector = LogAnomalyDetector.load("artifacts")
print(detector.predict("INFO Request processed successfully status=200"))
print(detector.predict("ERROR OutOfMemoryError: Java heap space"))
